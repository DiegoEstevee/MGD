# %%
from TradingviewData import TradingViewData,Interval

request = TradingViewData()

# %%
request.search('METAL','MCX')
# Out:
# Expecting value: line 1 column 1 (char 0)
# []

# %%
nifty_data = request.get_hist(symbol='LINKUSD',exchange='BINANCE',interval=Interval.daily,n_bars=1500)

nifty_data.to_csv("data_csv")

# %%
nifty_data
# Out:
#                               symbol       open       high        low  \
# datetime
# 2021-12-15 01:00:00  BINANCE:LINKUSD  18.466359  20.756978  17.257739
# 2021-12-16 01:00:00  BINANCE:LINKUSD  19.710976  20.387441  18.694021
# 2021-12-17 01:00:00  BINANCE:LINKUSD  18.795728  19.532356  17.536484
# 2021-12-18 01:00:00  BINANCE:LINKUSD  18.258267  20.334503  17.820244
# 2021-12-19 01:00:00  BINANCE:LINKUSD  19.540778  20.475314  18.684929
# ...                              ...        ...        ...        ...
# 2026-01-18 01:00:00  BINANCE:LINKUSD  13.731436  13.871785  13.305880
# 2026-01-19 01:00:00  BINANCE:LINKUSD  13.261481  13.261481  12.384190
# 2026-01-20 01:00:00  BINANCE:LINKUSD  12.899118  12.899118  12.028255
# 2026-01-21 01:00:00  BINANCE:LINKUSD  12.106663  12.654265  11.895477
# 2026-01-22 01:00:00  BINANCE:LINKUSD  12.401791  12.569486  12.113197
#
#                          close        volume
# datetime
# 2021-12-15 01:00:00  19.694958  1.896719e+06
# 2021-12-16 01:00:00  18.776511  1.197452e+06
# 2021-12-17 01:00:00  18.301817  1.498724e+06
# 2021-12-18 01:00:00  19.559275  1.533685e+06
# 2021-12-19 01:00:00  18.885889  1.301433e+06
# ...                        ...           ...
# 2026-01-18 01:00:00  13.327990  4.992477e+05
# 2026-01-19 01:00:00  12.876356  1.772122e+05
# 2026-01-20 01:00:00  12.111691  8.385107e+04
# 2026-01-21 01:00:00  12.390092  8.018361e+04
# 2026-01-22 01:00:00  12.282837  3.465255e+04
#
# [1500 rows x 6 columns]

# %%
nifty_data.isnull().value_counts()
# Out:
# symbol  open   high   low    close  volume
# False   False  False  False  False  False     1500
# Name: count, dtype: int64

# %%
nifty_data.isna().value_counts()
# Out:
# symbol  open   high   low    close  volume
# False   False  False  False  False  False     1500
# Name: count, dtype: int64

# %%
nifty_data.index.is_monotonic_increasing
# Out:
# True

# %%
nifty_data.index.has_duplicates
# Out:
# False

# %%
nifty_data.index.min(), nifty_data.index.max()
# Out:
# (Timestamp('2021-12-15 01:00:00'), Timestamp('2026-01-22 01:00:00'))

# %%
# nifty_futures = request.get_hist(symbol='LINKUSD',exchange='BINANCE',interval=Interval.hour_1,n_bars=1000,fut_contract=1)

# nifty_futures

# %%
# relience_data = request.get_hist(symbol='RELIANCE',exchange='NSE',interval=Interval.min_5,n_bars=5000)

# relience_data

# %%
# crudeoil_data = request.get_hist(symbol='LINKUSD',exchange='BINANCE',interval=Interval.daily,n_bars=5000)

# crudeoil_data

# %%
nifty_data.close.plot(figsize=(15,10),use_index=False)
# Out:
# <Axes: >
